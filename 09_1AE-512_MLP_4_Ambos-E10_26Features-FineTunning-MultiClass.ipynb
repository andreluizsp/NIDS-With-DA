# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import random_split, DataLoader, Dataset, ConcatDataset
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report

# Calculo de similaridade
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import pearsonr
from scipy.spatial.distance import euclidean
from scipy.spatial.distance import cityblock
from sklearn.metrics import jaccard_score

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import seaborn as sns

# Define seed
SEED = 42

# Set the seed for reproducibility
torch.manual_seed(SEED)
np.random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)  # For multi-GPU setups
torch.backends.cudnn.deterministic = True  # Ensure deterministic behavior
torch.backends.cudnn.benchmark = False    # Disable if you want deterministic results

Feature_ambos = [
                #'L4_SRC_PORT',
                #'L4_DST_PORT',
                'PROTOCOL',
                #'L7_PROTO',
                'IN_BYTES',
                'IN_PKTS',
                'OUT_BYTES',
                'OUT_PKTS',
                #'TCP_FLAGS',
                #'CLIENT_TCP_FLAGS',
                #'SERVER_TCP_FLAGS',
                'FLOW_DURATION_MILLISECONDS',
                'DURATION_IN', 
                'DURATION_OUT',
                #'MIN_TTL', 
                #'MAX_TTL',
                'LONGEST_FLOW_PKT',
                #'SHORTEST_FLOW_PKT',
                #'MIN_IP_PKT_LEN', 
                'MAX_IP_PKT_LEN', 
                'SRC_TO_DST_SECOND_BYTES', 
                'DST_TO_SRC_SECOND_BYTES',
                'RETRANSMITTED_IN_BYTES', 
                'RETRANSMITTED_IN_PKTS', 
                'RETRANSMITTED_OUT_BYTES', 
                'RETRANSMITTED_OUT_PKTS',
                'SRC_TO_DST_AVG_THROUGHPUT', 
                'DST_TO_SRC_AVG_THROUGHPUT', 
                'NUM_PKTS_UP_TO_128_BYTES',
                'NUM_PKTS_128_TO_256_BYTES', 
                'NUM_PKTS_256_TO_512_BYTES', 
                'NUM_PKTS_512_TO_1024_BYTES',
                'NUM_PKTS_1024_TO_1514_BYTES', 
                #'TCP_WIN_MAX_IN', 
                #'TCP_WIN_MAX_OUT', 
                'ICMP_TYPE', 
                'ICMP_IPV4_TYPE',
                #'DNS_QUERY_ID', 
                'DNS_QUERY_TYPE', 
                #'DNS_TTL_ANSWER',
                #'FTP_COMMAND_RET_CODE',
                'Label', 
                'Attack']

Feature_name = [f for f in Feature_ambos if f not in ['Label', 'Attack']]

input_dim = 26

# Mapear todos os ataques
# Mapear todos os ataques
map_attacks = {'Benign':0, 
              'DoS':1,
              'dos':1,
              'Reconnaissance':2,
              'DDoS':3,
              'ddos':3,
              'Theft':4,
              'ransomware':5,
              'scanning':6,
              'xss':7,
              'mitm':8,
              'password':9,
              'Backdoor':10,
              'backdoor':10,
              'Analysis':11,
              'Generic':12,
              'Exploits':13,
              'Bot':14,
              'DoS_attacks-SlowHTTPTest':15,
              'SSH-Bruteforce':16,
              'DoS_attacks-Hulk':17,
              'Infilteration':18,
              'DDOS_attack-HOIC':19, 
              'FTP-BruteForce':20,
              'Brute_Force_-Web':21, 
              'DDoS_attacks-LOIC-HTTP':22, 
              'DoS_attacks-GoldenEye':23,
              'DDOS_attack-LOIC-UDP':24, 
              'DoS_attacks-Slowloris':25, 
              'Brute_Force_-XSS':26,
              'SQL_Injection':27
              }

# %%
class AE1(nn.Module):
    def __init__(self, input_dim, latent_dim=32):
        super(AE1, self).__init__()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512), nn.ReLU(),
            nn.Linear(512, 256), nn.ReLU(),
            nn.Linear(256, 128), nn.ReLU(),
            nn.Linear(128, 64), nn.ReLU(),
            nn.Linear(64, latent_dim), nn.ReLU(),
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 64), nn.ReLU(),
            nn.Linear(64, 128), nn.ReLU(),
            nn.Linear(128, 256), nn.ReLU(),
            nn.Linear(256, 512),
            nn.Linear(512, input_dim)
        )

    def forward(self, x):
        x_enc = self.encoder(x)
        recon = self.decoder(x_enc)
        return recon, x_enc

# %%
def ae_loss(recon_x, x):
    recon_loss = F.mse_loss(recon_x, x, reduction='sum')
    return recon_loss

# %%
class MLP(nn.Module):
    def __init__(self, latent_dim):
        super(MLP, self).__init__()
        self.mlp = nn.Sequential(
            nn.Linear(latent_dim, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(True),
            nn.Dropout(0.3),

            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(True),
            nn.Dropout(0.3),

            nn.Linear(256, 64),
            nn.ReLU(True),
            nn.Dropout(0.2),

            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.mlp(x)

# %%
def get_datasets(dataset):
    
    if dataset == "dataset1":
         df = pd.read_csv('datasets/dataset1v2.csv') # NF-BoT-IoT-v2
    if dataset == "dataset2":
         df = pd.read_csv('datasets/dataset2v2.csv') # NF-ToN-IoT-v2
    if dataset == "dataset3":
         df = pd.read_csv('datasets/dataset3v2.csv') # NF-UNSW-NB15-v2
    if dataset == "dataset4":
         df = pd.read_csv('datasets/dataset4v2.csv') # NF-CICIDS2018-v3

    dataframe = df[Feature_ambos]
    
    return dataframe

# %%
def tensor_data(x_source1_train, y_source1_train):
    previsores_train = torch.tensor(np.array(x_source1_train), dtype = torch.float)
    class_train = torch.tensor(np.array(y_source1_train, dtype=np.float32), dtype = torch.float)
    dataset = torch.utils.data.TensorDataset(previsores_train, class_train)
    train_loader = torch.utils.data.DataLoader(dataset, batch_size=41)
    return previsores_train, class_train, dataset, train_loader

# %%
def inicia_datasets(treino):
      df = get_datasets(treino)
      print(f"Prepara {treino}: {df.shape}")
      x_split_train, y_split_train, x_split_val, y_split_val, x_split_test, y_split_test, z_split_test = preprocessing_data(df)
      print( x_split_train.shape, y_split_train.shape)
      print( x_split_val.shape, y_split_val.shape)
      print( x_split_test.shape, y_split_test.shape)
      dataset_train, class_train, dataset_train, loader_train = tensor_data( x_split_train,  y_split_train)
      dataset_val, class_val, dataset_val, loader_val = tensor_data( x_split_val,  y_split_val)
      dataset_test, class_test, dataset_test, loader_test = tensor_data( x_split_test,  y_split_test)
      return dataset_train, class_train, dataset_train, loader_train, dataset_val, class_val, dataset_val, loader_val, dataset_test, class_test, dataset_test, loader_test, z_split_test

# %%
def preprocessing_data(df):
    df_split = df.copy()
    df_split_label = df_split['Attack']
    df_split = df_split.drop('Attack',axis=1)
    df_split = df_split.drop('Label',axis=1)
    
    # Inicializando o MinMaxScaler (intervalo padrão é [0, 1])
    scaler = MinMaxScaler()

    # Ajustando e transformando os dados
    df_split = scaler.fit_transform(df_split)
    
    df_split_label = df_split_label.to_frame()
    x_split_train, x_split_temp, y_split_train, y_split_temp = train_test_split(df_split, df_split_label, test_size = 0.30, stratify=df_split_label)
    x_split_test, x_split_val, y_split_test, y_split_val = train_test_split(x_split_temp, y_split_temp, test_size = 0.50, stratify=y_split_temp)
    y_split_train['Attack'] = y_split_train['Attack'].apply(lambda x: 0 if x == 'Benign' else 1)
    z_split_test = y_split_test.copy()
    y_split_test['Attack'] = y_split_test['Attack'].apply(lambda x: 0 if x == 'Benign' else 1)
    #print(z_split_test)
    z_split_test['Attack']=z_split_test['Attack'].map(map_attacks)
    #z_test = torch.tensor(np.array(z_split_test, dtype=np.float32), dtype = torch.float)
    class_test = torch.tensor(np.array(y_split_test, dtype=np.float32), dtype = torch.float)
    class_attack = torch.tensor(np.array(z_split_test, dtype=np.float32), dtype = torch.float)
    dataset = torch.utils.data.TensorDataset(class_attack, class_test)
    z_test = torch.utils.data.DataLoader(dataset, batch_size=41)
    #print(z_split_test)
    y_split_val['Attack'] = y_split_val['Attack'].apply(lambda x: 0 if x == 'Benign' else 1)
    return x_split_train, y_split_train, x_split_val, y_split_val, x_split_test, y_split_test, z_test

# %%
dataset = "dataset1" 
dataset_train1, class_train1, dataset_train1, loader_train1, dataset_val1, class_val1, dataset_val1, loader_val1, dataset_test1, class_test1, dataset_test1, loader_test1, z_split_test1 = inicia_datasets(dataset)
dataset = "dataset2" 
dataset_train2, class_train2, dataset_train2, loader_train2, dataset_val2, class_val2, dataset_val2, loader_val2, dataset_test2, class_test2, dataset_test2, loader_test2, z_split_test2 = inicia_datasets(dataset)
dataset = "dataset3" 
dataset_train3, class_train3, dataset_train3, loader_train3, dataset_val3, class_val3, dataset_val3, loader_val3, dataset_test3, class_test3, dataset_test3, loader_test3, z_split_test3 = inicia_datasets(dataset)
dataset = "dataset4" 
dataset_train4, class_train4, dataset_train4, loader_train4, dataset_val4, class_val4, dataset_val4, loader_val4, dataset_test4, class_test4, dataset_test4, loader_test4, z_split_test4 = inicia_datasets(dataset)

# Gerar ambos para teste e validação
test_dataset_combined = ConcatDataset([dataset_test1, dataset_test2, dataset_test3, dataset_test4])
test_loader_combined = DataLoader(test_dataset_combined, batch_size=loader_test1.batch_size, shuffle=True)
val_dataset_combined = ConcatDataset([dataset_val1, dataset_val2, dataset_val3, dataset_val4])
val_loader_combined = DataLoader(val_dataset_combined, batch_size=loader_val1.batch_size, shuffle=True)
# Out:
# Prepara dataset1: (224511, 28)
# (157157, 26) (157157, 1)
# (33677, 26) (33677, 1)
# (33677, 26) (33677, 1)
# Prepara dataset2: (224512, 28)
# (157158, 26) (157158, 1)
# (33677, 26) (33677, 1)
# (33677, 26) (33677, 1)
# Prepara dataset3: (142152, 28)
# (99506, 26) (99506, 1)
# (21323, 26) (21323, 1)
# (21323, 26) (21323, 1)
# Prepara dataset4: (223976, 28)
# (156783, 26) (156783, 1)
# (33597, 26) (33597, 1)
# (33596, 26) (33596, 1)

# %%
def treina_modelo(modelo_AE1, modelo_MLP, input_dim, device):

    from sklearn.metrics import classification_report
    
    # Hiperparâmetros
    num_classes = 2
    epochs = 500
    lr = 0.001

    Alpha = 0.5
    Beta = 1
    
    patience = 50
    best_val_acc = 0
    epochs_no_improve = 0
    best_model_state = None
  
    # Otimizador conjunto
    params = list(modelo_MLP.parameters()) + list(modelo_AE1.parameters())   
    optimizer = torch.optim.Adam(params, lr=lr)

    # Scheduler: reduz o learning rate se a acurácia parar de melhorar
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=10, factor=0.5)

    # Funções de perda
    class_loss_fn = nn.BCEWithLogitsLoss()

    # Histórico
    loss_vals = []
    loss_valsAE = []
    loss_valsAE2 = []
    loss_valsAE3 = []
    loss_valsMLP = []
    val_simC = []
    val_distE = []
    val_distM = []
    val_accuracies = []
    val_losses = []

    for epoch in range(epochs):
        
        modelo_AE1.train()
        modelo_MLP.train()

        epoch_loss_recon = []
        epoch_loss_class = []
        epoch_loss_val = []
        epoch_simC = []
        epoch_corr = []
        epoch_distE = []
        epoch_distM = []
        epoch_simJ = []
        
        # Variaveis para similaridade
        simC = 0  # Cosseno 
        corr = 0  # Pearson 1.0 Correlação perfeita
        distE = 0  #  Eculidiana - Distância euclidiana
        distM = 0  # Distância de Manhattan
        simJ = 0  # Similaridade de Jaccard (para vetores binários ou conjuntos)

        for (X1, y1), (X2, y2), (X3, y3), (X4, y4) in zip(loader_train1, loader_train2, loader_train3, loader_train4):
    
            X = torch.cat([X1, X2, X3, X4], dim=0).to(device)
            y = torch.cat([y1, y2, y3, y4], dim=0).to(device).float()
            y = y.view(-1, 1)
            
            optimizer.zero_grad()
            
            # Forward do VAE1
            recon1, x_latent = modelo_AE1(X)
            
            # Perda de reconstrução (VAE1)
            recon_loss1 = ae_loss(recon1, X)
            
            # Classificação com vetor latente
            #x_latent = torch.cat([x_latent1, x_latent2, x_latent3], dim=1)
            outputs = modelo_MLP(x_latent)
            loss_class = F.binary_cross_entropy(outputs, y)

            # Perda total
            loss_recon = recon_loss1

            total_loss = ( loss_recon * Alpha ) + ( loss_class * Beta )

            total_loss.backward()
            optimizer.step()

            epoch_loss_recon.append(recon_loss1.item())
            epoch_loss_class.append(loss_class.item())
       
        # === Logs da época ===
        loss_epoch_recon = sum(epoch_loss_recon) / len(epoch_loss_recon)
        loss_epoch_class = sum(epoch_loss_class) / len(epoch_loss_class)
        
        loss_valsAE.append(loss_epoch_recon)
        loss_valsMLP.append(loss_epoch_class)
        
        print(f"Epoch {epoch+1:02d}/{epochs} | Recon: {loss_epoch_recon:.4f} | Class: {loss_epoch_class:.4f}")
        # Mostrar a simialridade da útlima instancia por época
        #print(f"Similaridade Média mu1, mu2 - Cosseno: {np.mean(simC)} | Euclidiana: {distE} | Manhattan: {distM}")
        modelo_AE1.eval()
        modelo_MLP.eval()
        all_preds, all_labels = [], []
        
        with torch.no_grad():
            
           for (X1, y1), (X2, y2), (X3, y3), (X4, y4) in zip(loader_val1, loader_val2, loader_val3, loader_val4):
    
               X = torch.cat([X1, X2, X3, X4], dim=0).to(device)
               y = torch.cat([y1, y2, y3, y4], dim=0).to(device).float()
               y = y.view(-1, 1)
            
               optimizer.zero_grad()
            
               # Forward do AE1
               recon1, x_latent = modelo_AE1(X)
            
               # Classificação com vetor latente
               outputs = modelo_MLP(x_latent)
               loss_class = F.binary_cross_entropy(outputs, y)
               
               preds = (outputs > 0.5).float()

               # Calcula loss (BCE para binário)
               loss = F.binary_cross_entropy(outputs, y)
               
               epoch_loss_val.append(loss.item())
               
               all_preds.append(preds.cpu())
               all_labels.append(y.cpu())

        all_preds_list = torch.cat(all_preds)
        all_labels_list = torch.cat(all_labels)
        acc = (all_preds_list.view(-1) == all_labels_list.view(-1)).float().mean().item()
        loss_val = sum(epoch_loss_val) / len(epoch_loss_val)
    
        val_accuracies.append(acc)
        val_losses.append(loss_val)
        print(f"Acurácia: {acc}")

        # Atualiza scheduler com base na acurácia de validação
        scheduler.step(acc)

        # Mostra o learning rate atual
        for param_group in optimizer.param_groups:
            current_lr = param_group['lr']
        print(f"Learning Rate atual: {current_lr:.6f}")        

        # Early stopping
        if acc > best_val_acc:
            best_val_acc = acc
            epochs_no_improve = 0
            best_model_state = modelo_MLP.state_dict()
        else:
            epochs_no_improve += 1
            print(f"Sem melhoria na validação por {epochs_no_improve} época(s).")
            if epochs_no_improve >= patience:
                print(f"Early stopping ativado na época {epoch+1}")
                break

    # Restaurar melhor modelo
    if best_model_state is not None:
        modelo_MLP.load_state_dict(best_model_state)
        print("Melhor modelo MLP restaurado com base na menor perda de validação.")  
        
    # === Plots ===
    plt.plot(loss_valsAE, label='Autoencoder')
    plt.plot(loss_valsMLP, label='MLP')
    plt.title('Treinamento - Perdas')
    plt.xlabel('Épocas')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    plt.plot(val_losses, label='MLP')
    plt.title('Validação: Perdas')
    plt.xlabel('Épocas')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    # Acurácia
    plt.subplot(1,2,2)
    plt.plot(val_accuracies, label='Validação', color='green')
    plt.title('Validação: Acurácia x Época')
    plt.xlabel('Época')
    plt.ylabel('Acurácia')
    plt.legend()
    plt.tight_layout()
    plt.show()
    return  all_preds, all_labels

# %%
# Instanciando o modelo
latent_dim = 32
modelo_AE1 = AE1(input_dim)
modelo_MLP = MLP(latent_dim)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
train_preds, train_labels = treina_modelo(modelo_AE1, modelo_MLP, input_dim, device)
# Out:
# Epoch 01/500 | Recon: 2.6892 | Class: 0.5056
# Acurácia: 0.793047308921814
# Learning Rate atual: 0.001000
# Epoch 02/500 | Recon: 0.2746 | Class: 0.3840
# Acurácia: 0.8411352634429932
# Learning Rate atual: 0.001000
# Epoch 03/500 | Recon: 0.2158 | Class: 0.3321
# Acurácia: 0.8535465598106384
# Learning Rate atual: 0.001000
# Epoch 04/500 | Recon: 0.2063 | Class: 0.3053
# Acurácia: 0.8781116008758545
# Learning Rate atual: 0.001000
# Epoch 05/500 | Recon: 0.1802 | Class: 0.2882
# Acurácia: 0.8779476881027222
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 06/500 | Recon: 0.1796 | Class: 0.2745
# Acurácia: 0.894316554069519
# Learning Rate atual: 0.001000
# Epoch 07/500 | Recon: 0.1534 | Class: 0.2649
# Acurácia: 0.9004051089286804
# Learning Rate atual: 0.001000
# Epoch 08/500 | Recon: 0.1437 | Class: 0.2560
# Acurácia: 0.8996089100837708
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 09/500 | Recon: 0.1590 | Class: 0.2504
# Acurácia: 0.855209231376648
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 2 época(s).
# Epoch 10/500 | Recon: 0.1296 | Class: 0.2421
# Acurácia: 0.917277455329895
# Learning Rate atual: 0.001000
# Epoch 11/500 | Recon: 0.1591 | Class: 0.2399
# Acurácia: 0.8853827714920044
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 12/500 | Recon: 0.1331 | Class: 0.2317
# Acurácia: 0.9037538170814514
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 2 época(s).
# Epoch 13/500 | Recon: 0.1174 | Class: 0.2254
# Acurácia: 0.9069737195968628
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 3 época(s).
# Epoch 14/500 | Recon: 0.1118 | Class: 0.2204
# Acurácia: 0.9112942814826965
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 4 época(s).
# Epoch 15/500 | Recon: 0.0969 | Class: 0.2038
# Acurácia: 0.9072430729866028
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 5 época(s).
# Epoch 16/500 | Recon: 0.0919 | Class: 0.1962
# Acurácia: 0.8246493339538574
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 6 época(s).
# Epoch 17/500 | Recon: 0.1025 | Class: 0.1904
# Acurácia: 0.9122778177261353
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 7 época(s).
# Epoch 18/500 | Recon: 0.1067 | Class: 0.1899
# Acurácia: 0.9163641929626465
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 8 época(s).
# Epoch 19/500 | Recon: 0.1074 | Class: 0.1879
# Acurácia: 0.8145446181297302
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 9 época(s).
# Epoch 20/500 | Recon: 0.0944 | Class: 0.1880
# Acurácia: 0.9244900941848755
# Learning Rate atual: 0.001000
# Epoch 21/500 | Recon: 0.0893 | Class: 0.1874
# Acurácia: 0.8258202075958252
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 22/500 | Recon: 0.1207 | Class: 0.1844
# Acurácia: 0.9060604572296143
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 2 época(s).
# Epoch 23/500 | Recon: 0.0922 | Class: 0.1809
# Acurácia: 0.8278341293334961
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 3 época(s).
# Epoch 24/500 | Recon: 0.1012 | Class: 0.1762
# Acurácia: 0.8987307548522949
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 4 época(s).
# Epoch 25/500 | Recon: 0.0913 | Class: 0.1823
# Acurácia: 0.9054399132728577
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 5 época(s).
# Epoch 26/500 | Recon: 0.0874 | Class: 0.1732
# Acurácia: 0.8225183486938477
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 6 época(s).
# Epoch 27/500 | Recon: 0.0887 | Class: 0.1730
# Acurácia: 0.8239350914955139
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 7 época(s).
# Epoch 28/500 | Recon: 0.0781 | Class: 0.1693
# Acurácia: 0.9190806150436401
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 8 época(s).
# Epoch 29/500 | Recon: 0.0906 | Class: 0.1708
# Acurácia: 0.9314099550247192
# Learning Rate atual: 0.001000
# Epoch 30/500 | Recon: 0.0764 | Class: 0.1660
# Acurácia: 0.9090930223464966
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 31/500 | Recon: 0.0717 | Class: 0.1671
# Acurácia: 0.9393719434738159
# Learning Rate atual: 0.001000
# Epoch 32/500 | Recon: 0.0750 | Class: 0.1656
# Acurácia: 0.8973959684371948
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 1 época(s).
# Epoch 33/500 | Recon: 0.0704 | Class: 0.1623
# Acurácia: 0.9196777939796448
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 2 época(s).
# Epoch 34/500 | Recon: 0.0693 | Class: 0.1612
# Acurácia: 0.9211296439170837
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 3 época(s).
# Epoch 35/500 | Recon: 0.0724 | Class: 0.1637
# Acurácia: 0.918050229549408
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 4 época(s).
# Epoch 36/500 | Recon: 0.0623 | Class: 0.1710
# Acurácia: 0.914397120475769
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 5 época(s).
# Epoch 37/500 | Recon: 0.0741 | Class: 0.2088
# Acurácia: 0.9160948991775513
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 6 época(s).
# Epoch 38/500 | Recon: 0.0602 | Class: 0.2031
# Acurácia: 0.8868580460548401
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 7 época(s).
# Epoch 39/500 | Recon: 0.0648 | Class: 0.2065
# Acurácia: 0.8965997695922852
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 8 época(s).
# Epoch 40/500 | Recon: 0.0819 | Class: 0.2021
# Acurácia: 0.8212069272994995
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 9 época(s).
# Epoch 41/500 | Recon: 0.0643 | Class: 0.1981
# Acurácia: 0.9180853962898254
# Learning Rate atual: 0.001000
# Sem melhoria na validação por 10 época(s).
# Epoch 42/500 | Recon: 0.0649 | Class: 0.1827
# Acurácia: 0.899386465549469
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 11 época(s).
# Epoch 43/500 | Recon: 0.0380 | Class: 0.1567
# Acurácia: 0.926176130771637
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 12 época(s).
# Epoch 44/500 | Recon: 0.0315 | Class: 0.1567
# Acurácia: 0.9250637888908386
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 13 época(s).
# Epoch 45/500 | Recon: 0.0325 | Class: 0.1590
# Acurácia: 0.8091468811035156
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 14 época(s).
# Epoch 46/500 | Recon: 0.0299 | Class: 0.1543
# Acurácia: 0.9513031840324402
# Learning Rate atual: 0.000500
# Epoch 47/500 | Recon: 0.0307 | Class: 0.1526
# Acurácia: 0.9175350666046143
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 1 época(s).
# Epoch 48/500 | Recon: 0.0293 | Class: 0.1502
# Acurácia: 0.9050300717353821
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 2 época(s).
# Epoch 49/500 | Recon: 0.0292 | Class: 0.1573
# Acurácia: 0.9184132218360901
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 3 época(s).
# Epoch 50/500 | Recon: 0.0326 | Class: 0.1487
# Acurácia: 0.8613329529762268
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 4 época(s).
# Epoch 51/500 | Recon: 0.0291 | Class: 0.1638
# Acurácia: 0.9021614193916321
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 5 época(s).
# Epoch 52/500 | Recon: 0.0281 | Class: 0.1827
# Acurácia: 0.8356438875198364
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 6 época(s).
# Epoch 53/500 | Recon: 0.0289 | Class: 0.1603
# Acurácia: 0.8439804911613464
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 7 época(s).
# Epoch 54/500 | Recon: 0.0306 | Class: 0.1480
# Acurácia: 0.9188230037689209
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 8 época(s).
# Epoch 55/500 | Recon: 0.0269 | Class: 0.1489
# Acurácia: 0.8395311832427979
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 9 época(s).
# Epoch 56/500 | Recon: 0.0266 | Class: 0.1447
# Acurácia: 0.9232606887817383
# Learning Rate atual: 0.000500
# Sem melhoria na validação por 10 época(s).
# Epoch 57/500 | Recon: 0.0267 | Class: 0.1435
# Acurácia: 0.8309252262115479
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 11 época(s).
# Epoch 58/500 | Recon: 0.0189 | Class: 0.1376
# Acurácia: 0.9077231287956238
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 12 época(s).
# Epoch 59/500 | Recon: 0.0181 | Class: 0.1362
# Acurácia: 0.9213052988052368
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 13 época(s).
# Epoch 60/500 | Recon: 0.0173 | Class: 0.1336
# Acurácia: 0.9441842436790466
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 14 época(s).
# Epoch 61/500 | Recon: 0.0170 | Class: 0.1338
# Acurácia: 0.8140645623207092
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 15 época(s).
# Epoch 62/500 | Recon: 0.0173 | Class: 0.1336
# Acurácia: 0.8169800639152527
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 16 época(s).
# Epoch 63/500 | Recon: 0.0164 | Class: 0.1323
# Acurácia: 0.8486055135726929
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 17 época(s).
# Epoch 64/500 | Recon: 0.0169 | Class: 0.1315
# Acurácia: 0.8305037021636963
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 18 época(s).
# Epoch 65/500 | Recon: 0.0161 | Class: 0.1314
# Acurácia: 0.8447415828704834
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 19 época(s).
# Epoch 66/500 | Recon: 0.0159 | Class: 0.1304
# Acurácia: 0.9576961994171143
# Learning Rate atual: 0.000250
# Epoch 67/500 | Recon: 0.0158 | Class: 0.1302
# Acurácia: 0.8180455565452576
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 1 época(s).
# Epoch 68/500 | Recon: 0.0155 | Class: 0.1285
# Acurácia: 0.9433060884475708
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 2 época(s).
# Epoch 69/500 | Recon: 0.0153 | Class: 0.1296
# Acurácia: 0.9300517439842224
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 3 época(s).
# Epoch 70/500 | Recon: 0.0155 | Class: 0.1280
# Acurácia: 0.8347305655479431
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 4 época(s).
# Epoch 71/500 | Recon: 0.0150 | Class: 0.1284
# Acurácia: 0.9546869993209839
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 5 época(s).
# Epoch 72/500 | Recon: 0.0147 | Class: 0.1281
# Acurácia: 0.8493665456771851
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 6 época(s).
# Epoch 73/500 | Recon: 0.0149 | Class: 0.1268
# Acurácia: 0.9528604745864868
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 7 época(s).
# Epoch 74/500 | Recon: 0.0144 | Class: 0.1264
# Acurácia: 0.8369669318199158
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 8 época(s).
# Epoch 75/500 | Recon: 0.0143 | Class: 0.1266
# Acurácia: 0.8390393853187561
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 9 época(s).
# Epoch 76/500 | Recon: 0.0142 | Class: 0.1260
# Acurácia: 0.8186661601066589
# Learning Rate atual: 0.000250
# Sem melhoria na validação por 10 época(s).
# Epoch 77/500 | Recon: 0.0140 | Class: 0.1265
# Acurácia: 0.842294454574585
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 11 época(s).
# Epoch 78/500 | Recon: 0.0113 | Class: 0.1221
# Acurácia: 0.955530047416687
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 12 época(s).
# Epoch 79/500 | Recon: 0.0110 | Class: 0.1220
# Acurácia: 0.9552841782569885
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 13 época(s).
# Epoch 80/500 | Recon: 0.0108 | Class: 0.1210
# Acurácia: 0.8392735719680786
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 14 época(s).
# Epoch 81/500 | Recon: 0.0107 | Class: 0.1208
# Acurácia: 0.960787296295166
# Learning Rate atual: 0.000125
# Epoch 82/500 | Recon: 0.0106 | Class: 0.1206
# Acurácia: 0.8334777355194092
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 1 época(s).
# Epoch 83/500 | Recon: 0.0106 | Class: 0.1208
# Acurácia: 0.9616303443908691
# Learning Rate atual: 0.000125
# Epoch 84/500 | Recon: 0.0105 | Class: 0.1206
# Acurácia: 0.9554364085197449
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 1 época(s).
# Epoch 85/500 | Recon: 0.0104 | Class: 0.1198
# Acurácia: 0.8328337669372559
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 2 época(s).
# Epoch 86/500 | Recon: 0.0104 | Class: 0.1198
# Acurácia: 0.840093195438385
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 3 época(s).
# Epoch 87/500 | Recon: 0.0105 | Class: 0.1200
# Acurácia: 0.9608692526817322
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 4 época(s).
# Epoch 88/500 | Recon: 0.0103 | Class: 0.1195
# Acurácia: 0.9538791179656982
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 5 época(s).
# Epoch 89/500 | Recon: 0.0102 | Class: 0.1189
# Acurácia: 0.8415451049804688
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 6 época(s).
# Epoch 90/500 | Recon: 0.0103 | Class: 0.1195
# Acurácia: 0.9315505027770996
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 7 época(s).
# Epoch 91/500 | Recon: 0.0102 | Class: 0.1191
# Acurácia: 0.955998420715332
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 8 época(s).
# Epoch 92/500 | Recon: 0.0101 | Class: 0.1184
# Acurácia: 0.9181556105613708
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 9 época(s).
# Epoch 93/500 | Recon: 0.0101 | Class: 0.1187
# Acurácia: 0.8274242877960205
# Learning Rate atual: 0.000125
# Sem melhoria na validação por 10 época(s).
# Epoch 94/500 | Recon: 0.0101 | Class: 0.1189
# Acurácia: 0.9561623334884644
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 11 época(s).
# Epoch 95/500 | Recon: 0.0091 | Class: 0.1163
# Acurácia: 0.8405381441116333
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 12 época(s).
# Epoch 96/500 | Recon: 0.0090 | Class: 0.1164
# Acurácia: 0.8412640690803528
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 13 época(s).
# Epoch 97/500 | Recon: 0.0090 | Class: 0.1158
# Acurácia: 0.8410884737968445
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 14 época(s).
# Epoch 98/500 | Recon: 0.0089 | Class: 0.1161
# Acurácia: 0.9622508883476257
# Learning Rate atual: 0.000063
# Epoch 99/500 | Recon: 0.0089 | Class: 0.1157
# Acurácia: 0.9627192616462708
# Learning Rate atual: 0.000063
# Epoch 100/500 | Recon: 0.0088 | Class: 0.1158
# Acurácia: 0.9624031186103821
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 1 época(s).
# Epoch 101/500 | Recon: 0.0088 | Class: 0.1151
# Acurácia: 0.9255438446998596
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 2 época(s).
# Epoch 102/500 | Recon: 0.0088 | Class: 0.1156
# Acurácia: 0.9622626304626465
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 3 época(s).
# Epoch 103/500 | Recon: 0.0088 | Class: 0.1153
# Acurácia: 0.842001736164093
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 4 época(s).
# Epoch 104/500 | Recon: 0.0088 | Class: 0.1150
# Acurácia: 0.8413928747177124
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 5 época(s).
# Epoch 105/500 | Recon: 0.0088 | Class: 0.1152
# Acurácia: 0.9363276362419128
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 6 época(s).
# Epoch 106/500 | Recon: 0.0087 | Class: 0.1150
# Acurácia: 0.8404210209846497
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 7 época(s).
# Epoch 107/500 | Recon: 0.0087 | Class: 0.1149
# Acurácia: 0.9477671384811401
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 8 época(s).
# Epoch 108/500 | Recon: 0.0087 | Class: 0.1147
# Acurácia: 0.9625436067581177
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 9 época(s).
# Epoch 109/500 | Recon: 0.0087 | Class: 0.1153
# Acurácia: 0.9456595778465271
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 10 época(s).
# Epoch 110/500 | Recon: 0.0086 | Class: 0.1143
# Acurácia: 0.9628480672836304
# Learning Rate atual: 0.000063
# Epoch 111/500 | Recon: 0.0086 | Class: 0.1144
# Acurácia: 0.9629300236701965
# Learning Rate atual: 0.000063
# Epoch 112/500 | Recon: 0.0086 | Class: 0.1146
# Acurácia: 0.9629534482955933
# Learning Rate atual: 0.000063
# Epoch 113/500 | Recon: 0.0086 | Class: 0.1147
# Acurácia: 0.9537737369537354
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 1 época(s).
# Epoch 114/500 | Recon: 0.0086 | Class: 0.1139
# Acurácia: 0.9616771936416626
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 2 época(s).
# Epoch 115/500 | Recon: 0.0086 | Class: 0.1140
# Acurácia: 0.9628012180328369
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 3 época(s).
# Epoch 116/500 | Recon: 0.0086 | Class: 0.1149
# Acurácia: 0.9628714323043823
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 4 época(s).
# Epoch 117/500 | Recon: 0.0085 | Class: 0.1139
# Acurácia: 0.841814398765564
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 5 época(s).
# Epoch 118/500 | Recon: 0.0085 | Class: 0.1141
# Acurácia: 0.9630821943283081
# Learning Rate atual: 0.000063
# Epoch 119/500 | Recon: 0.0085 | Class: 0.1137
# Acurácia: 0.9621338248252869
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 1 época(s).
# Epoch 120/500 | Recon: 0.0085 | Class: 0.1139
# Acurácia: 0.9626489877700806
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 2 época(s).
# Epoch 121/500 | Recon: 0.0085 | Class: 0.1137
# Acurácia: 0.9629417061805725
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 3 época(s).
# Epoch 122/500 | Recon: 0.0085 | Class: 0.1139
# Acurácia: 0.8406435251235962
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 4 época(s).
# Epoch 123/500 | Recon: 0.0084 | Class: 0.1136
# Acurácia: 0.9373814463615417
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 5 época(s).
# Epoch 124/500 | Recon: 0.0084 | Class: 0.1136
# Acurácia: 0.8407605886459351
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 6 época(s).
# Epoch 125/500 | Recon: 0.0084 | Class: 0.1132
# Acurácia: 0.9377561211585999
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 7 época(s).
# Epoch 126/500 | Recon: 0.0084 | Class: 0.1130
# Acurácia: 0.9339742064476013
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 8 época(s).
# Epoch 127/500 | Recon: 0.0084 | Class: 0.1137
# Acurácia: 0.963667631149292
# Learning Rate atual: 0.000063
# Epoch 128/500 | Recon: 0.0084 | Class: 0.1133
# Acurácia: 0.9628714323043823
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 1 época(s).
# Epoch 129/500 | Recon: 0.0084 | Class: 0.1131
# Acurácia: 0.9629300236701965
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 2 época(s).
# Epoch 130/500 | Recon: 0.0083 | Class: 0.1130
# Acurácia: 0.9630236625671387
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 3 época(s).
# Epoch 131/500 | Recon: 0.0083 | Class: 0.1133
# Acurácia: 0.9338922500610352
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 4 época(s).
# Epoch 132/500 | Recon: 0.0083 | Class: 0.1131
# Acurácia: 0.963187575340271
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 5 época(s).
# Epoch 133/500 | Recon: 0.0083 | Class: 0.1125
# Acurácia: 0.9623094201087952
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 6 época(s).
# Epoch 134/500 | Recon: 0.0083 | Class: 0.1127
# Acurácia: 0.9630705118179321
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 7 época(s).
# Epoch 135/500 | Recon: 0.0082 | Class: 0.1124
# Acurácia: 0.9629534482955933
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 8 época(s).
# Epoch 136/500 | Recon: 0.0082 | Class: 0.1129
# Acurácia: 0.8412289619445801
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 9 época(s).
# Epoch 137/500 | Recon: 0.0082 | Class: 0.1123
# Acurácia: 0.9636325240135193
# Learning Rate atual: 0.000063
# Sem melhoria na validação por 10 época(s).
# Epoch 138/500 | Recon: 0.0082 | Class: 0.1125
# Acurácia: 0.9637496471405029
# Learning Rate atual: 0.000031
# Epoch 139/500 | Recon: 0.0078 | Class: 0.1113
# Acurácia: 0.963655948638916
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 1 época(s).
# Epoch 140/500 | Recon: 0.0078 | Class: 0.1109
# Acurácia: 0.9638432860374451
# Learning Rate atual: 0.000031
# Epoch 141/500 | Recon: 0.0078 | Class: 0.1111
# Acurácia: 0.9638432860374451
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 1 época(s).
# Epoch 142/500 | Recon: 0.0077 | Class: 0.1111
# Acurácia: 0.9635856747627258
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 2 época(s).
# Epoch 143/500 | Recon: 0.0077 | Class: 0.1109
# Acurácia: 0.9636910557746887
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 3 época(s).
# Epoch 144/500 | Recon: 0.0077 | Class: 0.1106
# Acurácia: 0.9638667106628418
# Learning Rate atual: 0.000031
# Epoch 145/500 | Recon: 0.0077 | Class: 0.1111
# Acurácia: 0.9638316035270691
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 1 época(s).
# Epoch 146/500 | Recon: 0.0077 | Class: 0.1106
# Acurácia: 0.964124321937561
# Learning Rate atual: 0.000031
# Epoch 147/500 | Recon: 0.0077 | Class: 0.1109
# Acurácia: 0.9640189409255981
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 1 época(s).
# Epoch 148/500 | Recon: 0.0077 | Class: 0.1107
# Acurácia: 0.9642062783241272
# Learning Rate atual: 0.000031
# Epoch 149/500 | Recon: 0.0077 | Class: 0.1105
# Acurácia: 0.9638081789016724
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 1 época(s).
# Epoch 150/500 | Recon: 0.0077 | Class: 0.1106
# Acurácia: 0.9640306234359741
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 2 época(s).
# Epoch 151/500 | Recon: 0.0077 | Class: 0.1105
# Acurácia: 0.9632227420806885
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 3 época(s).
# Epoch 152/500 | Recon: 0.0077 | Class: 0.1103
# Acurácia: 0.9642179608345032
# Learning Rate atual: 0.000031
# Epoch 153/500 | Recon: 0.0077 | Class: 0.1110
# Acurácia: 0.9639018177986145
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 1 época(s).
# Epoch 154/500 | Recon: 0.0076 | Class: 0.1105
# Acurácia: 0.9637730121612549
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 2 época(s).
# Epoch 155/500 | Recon: 0.0076 | Class: 0.1104
# Acurácia: 0.9636208415031433
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 3 época(s).
# Epoch 156/500 | Recon: 0.0076 | Class: 0.1103
# Acurácia: 0.9640423655509949
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 4 época(s).
# Epoch 157/500 | Recon: 0.0076 | Class: 0.1104
# Acurácia: 0.9643701910972595
# Learning Rate atual: 0.000031
# Epoch 158/500 | Recon: 0.0076 | Class: 0.1101
# Acurácia: 0.9642764925956726
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 1 época(s).
# Epoch 159/500 | Recon: 0.0076 | Class: 0.1101
# Acurácia: 0.9644638299942017
# Learning Rate atual: 0.000031
# Epoch 160/500 | Recon: 0.0076 | Class: 0.1103
# Acurácia: 0.9642764925956726
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 1 época(s).
# Epoch 161/500 | Recon: 0.0076 | Class: 0.1102
# Acurácia: 0.9642882347106934
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 2 época(s).
# Epoch 162/500 | Recon: 0.0076 | Class: 0.1100
# Acurácia: 0.9641828536987305
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 3 época(s).
# Epoch 163/500 | Recon: 0.0076 | Class: 0.1099
# Acurácia: 0.9646511673927307
# Learning Rate atual: 0.000031
# Epoch 164/500 | Recon: 0.0076 | Class: 0.1101
# Acurácia: 0.9643350839614868
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 1 época(s).
# Epoch 165/500 | Recon: 0.0076 | Class: 0.1099
# Acurácia: 0.9642764925956726
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 2 época(s).
# Epoch 166/500 | Recon: 0.0076 | Class: 0.1100
# Acurácia: 0.9643584489822388
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 3 época(s).
# Epoch 167/500 | Recon: 0.0076 | Class: 0.1099
# Acurácia: 0.9643467664718628
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 4 época(s).
# Epoch 168/500 | Recon: 0.0076 | Class: 0.1098
# Acurácia: 0.9645224213600159
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 5 época(s).
# Epoch 169/500 | Recon: 0.0075 | Class: 0.1097
# Acurácia: 0.964428722858429
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 6 época(s).
# Epoch 170/500 | Recon: 0.0075 | Class: 0.1098
# Acurácia: 0.9640891551971436
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 7 época(s).
# Epoch 171/500 | Recon: 0.0075 | Class: 0.1095
# Acurácia: 0.9643701910972595
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 8 época(s).
# Epoch 172/500 | Recon: 0.0075 | Class: 0.1094
# Acurácia: 0.9645575284957886
# Learning Rate atual: 0.000031
# Sem melhoria na validação por 9 época(s).
# Epoch 173/500 | Recon: 0.0075 | Class: 0.1098
# Acurácia: 0.9646863341331482
# Learning Rate atual: 0.000031
# Epoch 174/500 | Recon: 0.0075 | Class: 0.1100
# Acurácia: 0.9643701910972595
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 1 época(s).
# Epoch 175/500 | Recon: 0.0073 | Class: 0.1094
# Acurácia: 0.9645809531211853
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 2 época(s).
# Epoch 176/500 | Recon: 0.0073 | Class: 0.1090
# Acurácia: 0.9644989967346191
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 3 época(s).
# Epoch 177/500 | Recon: 0.0073 | Class: 0.1087
# Acurácia: 0.9645224213600159
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 4 época(s).
# Epoch 178/500 | Recon: 0.0073 | Class: 0.1089
# Acurácia: 0.9645224213600159
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 5 época(s).
# Epoch 179/500 | Recon: 0.0073 | Class: 0.1086
# Acurácia: 0.9647682905197144
# Learning Rate atual: 0.000016
# Epoch 180/500 | Recon: 0.0073 | Class: 0.1090
# Acurácia: 0.9642882347106934
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 1 época(s).
# Epoch 181/500 | Recon: 0.0073 | Class: 0.1086
# Acurácia: 0.9645809531211853
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 2 época(s).
# Epoch 182/500 | Recon: 0.0073 | Class: 0.1086
# Acurácia: 0.964616060256958
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 3 época(s).
# Epoch 183/500 | Recon: 0.0073 | Class: 0.1087
# Acurácia: 0.9645692110061646
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 4 época(s).
# Epoch 184/500 | Recon: 0.0073 | Class: 0.1089
# Acurácia: 0.9644404649734497
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 5 época(s).
# Epoch 185/500 | Recon: 0.0073 | Class: 0.1089
# Acurácia: 0.9646745920181274
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 6 época(s).
# Epoch 186/500 | Recon: 0.0073 | Class: 0.1084
# Acurácia: 0.9644052982330322
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 7 época(s).
# Epoch 187/500 | Recon: 0.0073 | Class: 0.1088
# Acurácia: 0.964428722858429
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 8 época(s).
# Epoch 188/500 | Recon: 0.0073 | Class: 0.1084
# Acurácia: 0.9645224213600159
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 9 época(s).
# Epoch 189/500 | Recon: 0.0073 | Class: 0.1090
# Acurácia: 0.9646980166435242
# Learning Rate atual: 0.000016
# Sem melhoria na validação por 10 época(s).
# Epoch 190/500 | Recon: 0.0073 | Class: 0.1086
# Acurácia: 0.9647682905197144
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 11 época(s).
# Epoch 191/500 | Recon: 0.0072 | Class: 0.1082
# Acurácia: 0.9645106792449951
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 12 época(s).
# Epoch 192/500 | Recon: 0.0072 | Class: 0.1080
# Acurácia: 0.9646863341331482
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 13 época(s).
# Epoch 193/500 | Recon: 0.0071 | Class: 0.1081
# Acurácia: 0.9645926356315613
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 14 época(s).
# Epoch 194/500 | Recon: 0.0071 | Class: 0.1083
# Acurácia: 0.9646629095077515
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 15 época(s).
# Epoch 195/500 | Recon: 0.0071 | Class: 0.1082
# Acurácia: 0.9645926356315613
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 16 época(s).
# Epoch 196/500 | Recon: 0.0071 | Class: 0.1081
# Acurácia: 0.9648268222808838
# Learning Rate atual: 0.000008
# Epoch 197/500 | Recon: 0.0071 | Class: 0.1081
# Acurácia: 0.9646863341331482
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 1 época(s).
# Epoch 198/500 | Recon: 0.0071 | Class: 0.1082
# Acurácia: 0.9646394848823547
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 2 época(s).
# Epoch 199/500 | Recon: 0.0071 | Class: 0.1081
# Acurácia: 0.9649205207824707
# Learning Rate atual: 0.000008
# Epoch 200/500 | Recon: 0.0071 | Class: 0.1082
# Acurácia: 0.9647682905197144
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 1 época(s).
# Epoch 201/500 | Recon: 0.0071 | Class: 0.1079
# Acurácia: 0.9647331833839417
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 2 época(s).
# Epoch 202/500 | Recon: 0.0071 | Class: 0.1082
# Acurácia: 0.9648736715316772
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 3 época(s).
# Epoch 203/500 | Recon: 0.0071 | Class: 0.1079
# Acurácia: 0.9647097587585449
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 4 época(s).
# Epoch 204/500 | Recon: 0.0071 | Class: 0.1079
# Acurácia: 0.9648033976554871
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 5 época(s).
# Epoch 205/500 | Recon: 0.0071 | Class: 0.1076
# Acurácia: 0.9646863341331482
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 6 época(s).
# Epoch 206/500 | Recon: 0.0071 | Class: 0.1081
# Acurácia: 0.9648268222808838
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 7 época(s).
# Epoch 207/500 | Recon: 0.0071 | Class: 0.1080
# Acurácia: 0.9648385643959045
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 8 época(s).
# Epoch 208/500 | Recon: 0.0071 | Class: 0.1080
# Acurácia: 0.9648619294166565
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 9 época(s).
# Epoch 209/500 | Recon: 0.0071 | Class: 0.1079
# Acurácia: 0.9646629095077515
# Learning Rate atual: 0.000008
# Sem melhoria na validação por 10 época(s).
# Epoch 210/500 | Recon: 0.0071 | Class: 0.1079
# Acurácia: 0.9646394848823547
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 11 época(s).
# Epoch 211/500 | Recon: 0.0071 | Class: 0.1079
# Acurácia: 0.9647917151451111
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 12 época(s).
# Epoch 212/500 | Recon: 0.0071 | Class: 0.1080
# Acurácia: 0.9650024771690369
# Learning Rate atual: 0.000004
# Epoch 213/500 | Recon: 0.0071 | Class: 0.1079
# Acurácia: 0.9649205207824707
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 1 época(s).
# Epoch 214/500 | Recon: 0.0071 | Class: 0.1076
# Acurácia: 0.9648736715316772
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 2 época(s).
# Epoch 215/500 | Recon: 0.0071 | Class: 0.1080
# Acurácia: 0.9649205207824707
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 3 época(s).
# Epoch 216/500 | Recon: 0.0071 | Class: 0.1079
# Acurácia: 0.9648268222808838
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 4 época(s).
# Epoch 217/500 | Recon: 0.0071 | Class: 0.1078
# Acurácia: 0.9647799730300903
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 5 época(s).
# Epoch 218/500 | Recon: 0.0071 | Class: 0.1075
# Acurácia: 0.9648619294166565
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 6 época(s).
# Epoch 219/500 | Recon: 0.0071 | Class: 0.1078
# Acurácia: 0.964897096157074
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 7 época(s).
# Epoch 220/500 | Recon: 0.0071 | Class: 0.1076
# Acurácia: 0.9648736715316772
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 8 época(s).
# Epoch 221/500 | Recon: 0.0071 | Class: 0.1079
# Acurácia: 0.9651195406913757
# Learning Rate atual: 0.000004
# Epoch 222/500 | Recon: 0.0071 | Class: 0.1074
# Acurácia: 0.9648385643959045
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 1 época(s).
# Epoch 223/500 | Recon: 0.0071 | Class: 0.1074
# Acurácia: 0.9650024771690369
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 2 época(s).
# Epoch 224/500 | Recon: 0.0071 | Class: 0.1077
# Acurácia: 0.9650726914405823
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 3 época(s).
# Epoch 225/500 | Recon: 0.0071 | Class: 0.1077
# Acurácia: 0.9649322032928467
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 4 época(s).
# Epoch 226/500 | Recon: 0.0071 | Class: 0.1077
# Acurácia: 0.9649673104286194
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 5 época(s).
# Epoch 227/500 | Recon: 0.0071 | Class: 0.1076
# Acurácia: 0.9648151397705078
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 6 época(s).
# Epoch 228/500 | Recon: 0.0070 | Class: 0.1072
# Acurácia: 0.9650259017944336
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 7 época(s).
# Epoch 229/500 | Recon: 0.0070 | Class: 0.1076
# Acurácia: 0.9650375843048096
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 8 época(s).
# Epoch 230/500 | Recon: 0.0070 | Class: 0.1077
# Acurácia: 0.9647214412689209
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 9 época(s).
# Epoch 231/500 | Recon: 0.0070 | Class: 0.1075
# Acurácia: 0.9648268222808838
# Learning Rate atual: 0.000004
# Sem melhoria na validação por 10 época(s).
# Epoch 232/500 | Recon: 0.0070 | Class: 0.1075
# Acurácia: 0.9649322032928467
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 11 época(s).
# Epoch 233/500 | Recon: 0.0070 | Class: 0.1073
# Acurácia: 0.9649907350540161
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 12 época(s).
# Epoch 234/500 | Recon: 0.0070 | Class: 0.1074
# Acurácia: 0.9650024771690369
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 13 época(s).
# Epoch 235/500 | Recon: 0.0070 | Class: 0.1076
# Acurácia: 0.9649556279182434
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 14 época(s).
# Epoch 236/500 | Recon: 0.0070 | Class: 0.1075
# Acurácia: 0.9649322032928467
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 15 época(s).
# Epoch 237/500 | Recon: 0.0070 | Class: 0.1074
# Acurácia: 0.9648619294166565
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 16 época(s).
# Epoch 238/500 | Recon: 0.0070 | Class: 0.1071
# Acurácia: 0.9648853540420532
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 17 época(s).
# Epoch 239/500 | Recon: 0.0070 | Class: 0.1074
# Acurácia: 0.9649322032928467
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 18 época(s).
# Epoch 240/500 | Recon: 0.0070 | Class: 0.1073
# Acurácia: 0.9650141596794128
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 19 época(s).
# Epoch 241/500 | Recon: 0.0070 | Class: 0.1077
# Acurácia: 0.9651078581809998
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 20 época(s).
# Epoch 242/500 | Recon: 0.0070 | Class: 0.1074
# Acurácia: 0.9650141596794128
# Learning Rate atual: 0.000002
# Sem melhoria na validação por 21 época(s).
# Epoch 243/500 | Recon: 0.0070 | Class: 0.1074
# Acurácia: 0.9650259017944336
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 22 época(s).
# Epoch 244/500 | Recon: 0.0070 | Class: 0.1074
# Acurácia: 0.9650375843048096
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 23 época(s).
# Epoch 245/500 | Recon: 0.0070 | Class: 0.1074
# Acurácia: 0.9650259017944336
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 24 época(s).
# Epoch 246/500 | Recon: 0.0070 | Class: 0.1073
# Acurácia: 0.9650141596794128
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 25 época(s).
# Epoch 247/500 | Recon: 0.0070 | Class: 0.1073
# Acurácia: 0.9649322032928467
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 26 época(s).
# Epoch 248/500 | Recon: 0.0070 | Class: 0.1074
# Acurácia: 0.9650024771690369
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 27 época(s).
# Epoch 249/500 | Recon: 0.0070 | Class: 0.1072
# Acurácia: 0.9649322032928467
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 28 época(s).
# Epoch 250/500 | Recon: 0.0070 | Class: 0.1072
# Acurácia: 0.9650141596794128
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 29 época(s).
# Epoch 251/500 | Recon: 0.0070 | Class: 0.1076
# Acurácia: 0.9649438858032227
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 30 época(s).
# Epoch 252/500 | Recon: 0.0070 | Class: 0.1073
# Acurácia: 0.9651078581809998
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 31 época(s).
# Epoch 253/500 | Recon: 0.0070 | Class: 0.1071
# Acurácia: 0.9650024771690369
# Learning Rate atual: 0.000001
# Sem melhoria na validação por 32 época(s).
# Epoch 254/500 | Recon: 0.0070 | Class: 0.1075
# Acurácia: 0.9649322032928467
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 33 época(s).
# Epoch 255/500 | Recon: 0.0070 | Class: 0.1078
# Acurácia: 0.9650024771690369
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 34 época(s).
# Epoch 256/500 | Recon: 0.0070 | Class: 0.1072
# Acurácia: 0.96490877866745
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 35 época(s).
# Epoch 257/500 | Recon: 0.0070 | Class: 0.1076
# Acurácia: 0.964897096157074
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 36 época(s).
# Epoch 258/500 | Recon: 0.0070 | Class: 0.1074
# Acurácia: 0.964897096157074
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 37 época(s).
# Epoch 259/500 | Recon: 0.0070 | Class: 0.1071
# Acurácia: 0.9649673104286194
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 38 época(s).
# Epoch 260/500 | Recon: 0.0070 | Class: 0.1073
# Acurácia: 0.9650259017944336
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 39 época(s).
# Epoch 261/500 | Recon: 0.0070 | Class: 0.1074
# Acurácia: 0.9649438858032227
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 40 época(s).
# Epoch 262/500 | Recon: 0.0070 | Class: 0.1078
# Acurácia: 0.9649790525436401
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 41 época(s).
# Epoch 263/500 | Recon: 0.0070 | Class: 0.1075
# Acurácia: 0.9649205207824707
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 42 época(s).
# Epoch 264/500 | Recon: 0.0070 | Class: 0.1071
# Acurácia: 0.9649790525436401
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 43 época(s).
# Epoch 265/500 | Recon: 0.0070 | Class: 0.1074
# Acurácia: 0.9649556279182434
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 44 época(s).
# Epoch 266/500 | Recon: 0.0070 | Class: 0.1070
# Acurácia: 0.9649438858032227
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 45 época(s).
# Epoch 267/500 | Recon: 0.0070 | Class: 0.1075
# Acurácia: 0.9649673104286194
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 46 época(s).
# Epoch 268/500 | Recon: 0.0070 | Class: 0.1071
# Acurácia: 0.9649907350540161
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 47 época(s).
# Epoch 269/500 | Recon: 0.0070 | Class: 0.1071
# Acurácia: 0.9649205207824707
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 48 época(s).
# Epoch 270/500 | Recon: 0.0070 | Class: 0.1076
# Acurácia: 0.9649907350540161
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 49 época(s).
# Epoch 271/500 | Recon: 0.0070 | Class: 0.1073
# Acurácia: 0.9649205207824707
# Learning Rate atual: 0.000000
# Sem melhoria na validação por 50 época(s).
# Early stopping ativado na época 271
# Melhor modelo MLP restaurado com base na menor perda de validação.

# %%
def testa(target_test, treino, labels_test):
  # Valida source
  modelo_AE1.eval()
  modelo_MLP.eval()
  all_preds, all_labels, all_attacks = [], [], []

  with torch.no_grad():
      
    for (X, y), (z, y2) in zip(target_test, labels_test):

         X = X.to(device)
         y = y.to(device).float()
         y = y.view(-1, 1)
         z = z.to(device).float()
         z = z.view(-1, 1)
        
            
         # Forward do VAE1, VAE2 e VAE3
         recon1, x_latent = modelo_AE1(X)
            
         # Classificação com vetor latente
         outputs = modelo_MLP(x_latent)
         loss_class = F.binary_cross_entropy(outputs, y)
               
         preds = (outputs > 0.5).float()

         # Calcula loss (BCE para binário)
         loss = F.binary_cross_entropy(outputs, y)
               
         all_preds.append(preds.cpu())
         all_labels.append(y.cpu())
         all_attacks.append(z.cpu())
        
  all_preds_list = torch.cat(all_preds)
  all_labels_list = torch.cat(all_labels)
  all_attacks_list = torch.cat(all_attacks)

  #print(all_attacks_list.view(-1))

  acc = (all_preds_list.view(-1) == all_labels_list.view(-1)).float().mean().item()

  # Matriz de confusão
  matriz2 = confusion_matrix(all_preds_list.numpy().round(), all_labels_list.numpy().round())
  sns.set(rc={"figure.figsize": (6, 6)})
  title = "Matriz de Confusão: " + treino
  sns.heatmap(matriz2/np.sum(matriz2), annot=True, annot_kws={'size': 10}, fmt='.2%', cmap='Blues').set_title(title)
  plt.show()

  # Extração dos elementos da matriz (para problema binário)
  TN, FP, FN, TP = matriz2.ravel()

  # Cálculo das métricas
  TPR = TP / (TP + FN) if (TP + FN) != 0 else 0  # Sensibilidade, Recall
  TNR = TN / (TN + FP) if (TN + FP) != 0 else 0  # Especificidade
  F1 = f1_score(all_labels_list.detach().numpy().round(), all_preds_list.detach().numpy().round())
  return TPR, TNR, F1, acc, all_preds_list.view(-1), all_labels_list.view(-1), all_attacks_list.view(-1)

# %%
datasets = ["dataset1", "dataset2", "dataset3", "dataset4"]
target_test = [loader_test1, loader_test2, loader_test3, loader_test4]
labels_test = [z_split_test1, z_split_test2, z_split_test3, z_split_test4]

TPRs = []
TNRs = []
F1s = []
ACCs = []
all_preds_lists = []
all_labels_lists = []
all_attacks_lists = []

for data, teste, labels  in zip(datasets, target_test, labels_test):
    print(f"Treinando com Ambos e validando com {data}")
    TPR, TNR, F1, acc, all_preds_list, all_labels_list, all_attacks_list = testa(teste, data, labels)
    TPRs.append(TPR)
    TNRs.append(TNR)
    F1s.append(F1)
    ACCs.append(acc)
    all_preds_lists.extend(all_preds_list)
    all_labels_lists.extend(all_labels_list)
    all_attacks_lists.extend(all_attacks_list)
    
# Criação da tabela
df = pd.DataFrame({
    'Dataset': datasets,
    'TPR': TPRs,
    'TNR': TNRs,
    'F1-Score': F1s,
    'Acurácia': ACCs
})
print("----------------------------------------------")
print("Resumo da validação nos Datasets:")
print(df)
print("----------------------------------------------")
# Out:
# Treinando com Ambos e validando com dataset1
# Treinando com Ambos e validando com dataset2
# Treinando com Ambos e validando com dataset3
# Treinando com Ambos e validando com dataset4
# ----------------------------------------------
# Resumo da validação nos Datasets:
#     Dataset       TPR       TNR  F1-Score  Acurácia
# 0  dataset1  0.974581  0.970150  0.972289  0.972355
# 1  dataset2  0.918615  0.950028  0.934932  0.933753
# 2  dataset3  0.991982  0.996886  0.994439  0.994419
# 3  dataset4  0.995063  0.928996  0.958173  0.959668
# ----------------------------------------------

# %%
# Combinar todas as predições em um dataframe para tabulação

all_labels = [t.item() for t in all_labels_lists]
all_preds = [t.item() for t in all_preds_lists]
all_attacks = [t.item() for t in all_attacks_lists]

# Inverter dicionario
map_attacks_inv = {v: k for k, v in map_attacks.items()}

df = pd.DataFrame({
    "Real": all_labels,
    "Previsto": all_preds,
    "Ataque": all_attacks
})

# Criar coluna de acerto/erro
df["Acertou"] = df["Real"] == df["Previsto"]

# Agrupar predições por tipo de ataque
tabela = df.groupby("Ataque").agg(
    Total=("Real","count"),
    Acertos=("Acertou","sum")
)

# Adicionar Acurácia por ataque
tabela["Acurácia"] = tabela["Acertos"] / tabela["Total"]

# Adicionar F1 por ataque
f1_por_ataque = {}
TP_por_ataque = {}
TN_por_ataque = {}
FP_por_ataque = {}
FN_por_ataque = {}
for atk, grupo in df.groupby("Ataque"):
    f1_por_ataque[atk] = f1_score(grupo["Real"], grupo["Previsto"], zero_division=0)
    TP_por_ataque[atk] = ((grupo["Real"] == 1) & (grupo["Previsto"] == 1)).sum()
    TN_por_ataque[atk] = ((grupo["Real"] == 0) & (grupo["Previsto"] == 0)).sum()
    FP_por_ataque[atk] = ((grupo["Real"] == 0) & (grupo["Previsto"] == 1)).sum()
    FN_por_ataque[atk] = ((grupo["Real"] == 1) & (grupo["Previsto"] == 0)).sum()

tabela["TP"] = tabela.index.map(TP_por_ataque)
tabela["TN"] = tabela.index.map(TN_por_ataque)
tabela["FP"] = tabela.index.map(FP_por_ataque)
tabela["FN"] = tabela.index.map(FN_por_ataque)
tabela["F1"] = tabela.index.map(f1_por_ataque)


# Renomear indice pelo nome do ataque
tabela.index = tabela.index.map(map_attacks_inv)

print("Resumo por tipo de ataque:")
print(tabela)
# Out:
# Resumo por tipo de ataque:
#                           Total  Acertos  Acurácia    TP     TN    FP    FN  \
# Ataque
# Benign                    61125    59116  0.967133     0  59116  2009     0
# dos                        8526     8509  0.998006  8509      0     0    17
# Reconnaissance             7408     7005  0.945599  7005      0     0   403
# ddos                       9825     9631  0.980254  9631      0     0   194
# Theft                       365      362  0.991781   362      0     0     3
# ransomware                  514      479  0.931907   479      0     0    35
# scanning                   2166     1710  0.789474  1710      0     0   456
# xss                        2167     2129  0.982464  2129      0     0    38
# mitm                       1159     1067  0.920621  1067      0     0    92
# password                   2166     2085  0.962604  2085      0     0    81
# backdoor                   2492     2485  0.997191  2485      0     0     7
# Analysis                    345      345  1.000000   345      0     0     0
# Generic                    2484     2480  0.998390  2480      0     0     4
# Exploits                   4733     4714  0.995986  4714      0     0    19
# Bot                        1650     1648  0.998788  1648      0     0     2
# DoS_attacks-SlowHTTPTest   1500     1500  1.000000  1500      0     0     0
# SSH-Bruteforce             1650     1650  1.000000  1650      0     0     0
# DoS_attacks-Hulk           1500     1500  1.000000  1500      0     0     0
# Infilteration              1650      458  0.277576   458      0     0  1192
# DDOS_attack-HOIC           1650     1650  1.000000  1650      0     0     0
# FTP-BruteForce             1650     1650  1.000000  1650      0     0     0
# Brute_Force_-Web            243      225  0.925926   225      0     0    18
# DDoS_attacks-LOIC-HTTP     1650     1592  0.964848  1592      0     0    58
# DoS_attacks-GoldenEye      1500     1500  1.000000  1500      0     0     0
# DDOS_attack-LOIC-UDP        517      517  1.000000   517      0     0     0
# DoS_attacks-Slowloris      1500     1498  0.998667  1498      0     0     2
# Brute_Force_-XSS             72       66  0.916667    66      0     0     6
# SQL_Injection                66       66  1.000000    66      0     0     0
#
#                                 F1
# Ataque
# Benign                    0.000000
# dos                       0.999002
# Reconnaissance            0.972039
# ddos                      0.990029
# Theft                     0.995873
# ransomware                0.964753
# scanning                  0.882353
# xss                       0.991155
# mitm                      0.958670
# password                  0.980946
# backdoor                  0.998594
# Analysis                  1.000000
# Generic                   0.999194
# Exploits                  0.997989
# Bot                       0.999394
# DoS_attacks-SlowHTTPTest  1.000000
# SSH-Bruteforce            1.000000
# DoS_attacks-Hulk          1.000000
# Infilteration             0.434535
# DDOS_attack-HOIC          1.000000
# FTP-BruteForce            1.000000
# Brute_Force_-Web          0.961538
# DDoS_attacks-LOIC-HTTP    0.982110
# DoS_attacks-GoldenEye     1.000000
# DDOS_attack-LOIC-UDP      1.000000
# DoS_attacks-Slowloris     0.999333
# Brute_Force_-XSS          0.956522
# SQL_Injection             1.000000
